# %%
import os
import pandas as pd
from IPython.display import HTML 

from main import OUTPUT_FOLDER
from scripts.jupyter.wdc_word_frequency_bar import show_frequency_bar

# --------- frequency bar ---------
frequency_df = pd.read_json(os.path.join(OUTPUT_FOLDER, 'wdc', 'word_count.json'))

freq = show_frequency_bar(frequency_df, page=1, items=30)
display(HTML(freq.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>word</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>shoes</td>
#       <td>4604</td>
#     </tr>
#     <tr>
#       <td>black</td>
#       <td>4428</td>
#     </tr>
#     <tr>
#       <td>men</td>
#       <td>4024</td>
#     </tr>
#     <tr>
#       <td>women</td>
#       <td>3492</td>
#     </tr>
#     <tr>
#       <td>shopbop</td>
#       <td>2385</td>
#     </tr>
#     <tr>
#       <td>nike</td>
#       <td>2329</td>
#     </tr>
#     <tr>
#       <td>running</td>
#       <td>2159</td>
#     </tr>
#     <tr>
#       <td>boots</td>
#       <td>1927</td>
#     </tr>
#     <tr>
#       <td>com</td>
#       <td>1912</td>
#     </tr>
#     <tr>
#       <td>training</td>
#       <td>1814</td>
#     </tr>
#     <tr>
#       <td>white</td>
#       <td>1747</td>
#     </tr>
#     <tr>
#       <td>new</td>
#       <td>1640</td>
#     </tr>
#     <tr>
# ...
