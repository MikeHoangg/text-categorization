# %%
import os
import pandas as pd
from IPython.display import HTML 

from main import OUTPUT_FOLDER
from scripts.jupyter.wdc_word_frequency_bar import show_frequency_bar
from scripts.jupyter.wdc_word_similarity import show_similarity_bar

# --------- frequency bar ---------
frequency_df = pd.read_json(os.path.join(OUTPUT_FOLDER, 'word_count.json'))

freq = show_frequency_bar(frequency_df, page=1, items=10)
display(HTML(freq.to_html(index=False)))

# --------- similarity bar ---------
similarity_df = pd.read_json(os.path.join(OUTPUT_FOLDER, 'word_similarity.json'))

word = 'dakinescrambler'
sim = show_similarity_bar(similarity_df, word, page=1, items=10)
display(HTML(sim.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>word</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>s</td>
#       <td>6868</td>
#     </tr>
#     <tr>
#       <td>shoes</td>
#       <td>4604</td>
#     </tr>
#     <tr>
#       <td>black</td>
#       <td>4428</td>
#     </tr>
#     <tr>
#       <td>men</td>
#       <td>4024</td>
#     </tr>
#     <tr>
#       <td>women</td>
#       <td>3492</td>
#     </tr>
#     <tr>
#       <td>and</td>
#       <td>2671</td>
#     </tr>
#     <tr>
#       <td>shopbop</td>
#       <td>2385</td>
#     </tr>
#     <tr>
#       <td>nike</td>
#       <td>2329</td>
#     </tr>
#     <tr>
#       <td>running</td>
#       <td>2159</td>
#     </tr>
#     <tr>
#       <td>up</td>
#       <td>2103</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>word</th>
# ...
